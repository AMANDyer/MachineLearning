# %%
# machine learning models
#(1)...> Supervised Models ....> Data with labels (columns name) provided
#(2)..> Unsupervised Models .... only data provided

# %%
#(1). Supervised ML Models
#(a). LinearRegression
#(b)  logisticRegression
#(c). Decision tree
#(d). RnadomForest
#(e). Naive bayes
#(f). SVM

#(2)Unsupervised ML Models
#(a). PCA
#(b). KMeans
#(c). Aprioro

# %%
#what does ML Model???
# Data .... divide(input,target)....
#train and test data ....
# machine(x_train,y_train)
#machine(x_test)....> predict ....> y_pred
#y_test
#metrics_score(y_test,y_pred)

# %%
#(1)  LinearRegression
# it will work when we have target column as Numerical.

# %%
#input      output
#1+1         2
#2+3         5
#5+6         11


#model([1+1 ,2+3],[2,5]) .....> model(5+6)..... > ????? ....> 15 <......y_pred
# y_test =11
#metrics_score (y_test,y_pred)

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('insurance - insurance.csv')

# %%
#df.isnull().sum(0

# %%
df=pd.get_dummies(df,columns=['sex','region','smoker'])

# %%
df.head(3)
# Out:
#    age    bmi  children     charges  sex_female  sex_male  region_northeast  \
# 0   19  27.90         0  16884.9240        True     False             False
# 1   18  33.77         1   1725.5523       False      True             False
# 2   28  33.00         3   4449.4620       False      True             False
#
#    region_northwest  region_southeast  region_southwest  smoker_no  smoker_yes
# 0             False             False              True      False        True
# 1             False              True             False       True       False
# 2             False              True             False       True       False

# %%
x=df.drop(columns=['charges'])
y=df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 0.7835929767120722

# %%
df=pd.read_csv('tips - tips.csv')
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
df=pd.get_dummies(df,columns=['sex','smoker','day','time'])
df.head(3)
# Out:
#    total_bill   tip  size  sex_Female  sex_Male  smoker_No  smoker_Yes  \
# 0       16.99  1.01     2        True     False       True       False
# 1       10.34  1.66     3       False      True       True       False
# 2       21.01  3.50     3       False      True       True       False
#
#    day_Fri  day_Sat  day_Sun  day_Thur  time_Dinner  time_Lunch
# 0    False    False     True     False         True       False
# 1    False    False     True     False         True       False
# 2    False    False     True     False         True       False

# %%
x=df.drop(columns=['total_bill'])
y=df['total_bill']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
r2_score(y_test , y_pred)
# Out:
# 0.624080871429097
